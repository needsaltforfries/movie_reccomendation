# %%
import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torchvision import transforms
from torch.autograd import Variable

import numpy as np
import pandas as pd
import difflib
import os

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader

from IPython import display
import string
import dataloader
from dataloader import MoviesDataset
#load data
movies = pd.read_csv('tmdb_5000_movies.csv')
movies = movies.iloc[:-3]
features = ['title', 'genres', 'keywords', 'original_language', 'vote_average']

# make dataset
dataset = MoviesDataset(movies)

#clean null values
for feature in features:
    movies[feature] = movies[feature].fillna('Unknown')

scaler = StandardScaler()

weight_title = 2.0  # Increase the weight of title
weight_genre = 1.5  # Increase the weight of genre

vectorizer_title = TfidfVectorizer()
vectorizer_genre = TfidfVectorizer()
vectorizer_keywords = TfidfVectorizer()
vectorizer_language = TfidfVectorizer()

title_features = movies['title']
genre_features = movies['genres']
keywords_features = movies['keywords']
language_features = movies['original_language']

title_vec = vectorizer_title.fit_transform(title_features)
genre_vec = vectorizer_genre.fit_transform(genre_features)
keywords_vec = vectorizer_keywords.fit_transform(keywords_features)
language_vec = vectorizer_language.fit_transform(language_features)

title_vec_scaled = scaler.fit_transform(title_vec.toarray())
genre_vec_scaled = scaler.fit_transform(genre_vec.toarray())
keywords_vec_scaled = scaler.fit_transform(keywords_vec.toarray())
language_vec_scaled = scaler.fit_transform(language_vec.toarray())
vote_avg = movies['vote_average'].values.reshape(-1, 1)


feat_vectors = np.concatenate([
    weight_title * title_vec_scaled,
    weight_genre * genre_vec_scaled,
    keywords_vec_scaled,
    language_vec_scaled
], axis=1)
feat_vectors = np.concatenate([feat_vectors, vote_avg], axis=1)

svd = TruncatedSVD(n_components=32) 
reduced_features = svd.fit_transform(feat_vectors).astype(np.float32)

similarity = cosine_similarity(reduced_features)
print(similarity.shape)
# Out:
# (4800, 4800)

# %%
from network import Reccomender

def init_weights(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1 or classname.find('BatchNorm') != -1:
        m.weight.data.normal_(0.00, 0.02)
        
#set up rec
batch_size = 128
rec = Reccomender(batch_size)
rec.apply(init_weights)

#load model if possible
loadModel = False
if os.path.exists('./model.pth') and loadModel:
    rec.load_state_dict(torch.load('./model.pth'))

if torch.cuda.is_available():
    rec.cuda()
    
optimizer = Adam(rec.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
#training functions
loss = nn.L1Loss()
movie_titles = movies['title'].tolist()

def train_network(optimizer, results, real_data, n_batch):
    optimizer.zero_grad()

    gt_similar =  similarity[n_batch]
    most_similar_idxs = np.argsort(gt_similar)[::-1]
    similar_movs = [movies.iloc[most_similar_idxs[1]]['title'], 
                    movies.iloc[most_similar_idxs[2]]['title'], 
                    movies.iloc[most_similar_idxs[3]]['title']]
    print(f"Ground-Truth Similarity | `{movies.iloc[most_similar_idxs[0]]['title']}` : `{similar_movs}`")
    #output of neural network should be an integer close to MSM
    sample = results[0].detach().cpu().numpy()
    sample = sample.reshape(1, -1)
    sim = torch.tensor(cosine_similarity(sample, reduced_features))
    closest_index = torch.argmax(sim).item()
        
    print(f"Reccomendation | {movies.iloc[closest_index]['title']} : {dataset.GetSimilarItems(sample, top_n=3)}")
    error = loss(real_data, results.unsqueeze(1))
    error.backward()
    optimizer.step()
    
    prediction = rec(real_data)
    return error, prediction

# %%
num_batches = len(dataset)//batch_size
num_epochs = 300

train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
#training loop
for epoch in range(num_epochs):
    for n_batch, batch in enumerate(train_loader):
        real_data = Variable(batch)
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        real_data = real_data.unsqueeze(1)
        print(real_data.shape)
        result = rec(real_data)
        print("NETWORK FORWARDED")
        # print(f"GT{real_data[0]} \n RESULT{result[0]}")
        # print(f"result shape - {result.shape}")
        err, pred = train_network(optimizer, result, real_data, n_batch)
        result = result.detach()
        #show progress
        print(f"iter: {n_batch}/{num_batches} of epoch {epoch}/{num_epochs}")
        print(f"err: {err:.6f}\n")
    display.clear_output(True)
torch.save(rec.state_dict(), './reccomender_model.pth')
# Out:
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `avatar` : `['tomorrowland', 'the time machine', 'insurgent']`
# Reccomendation | the invasion : ['planet of the apes', 'battle for the planet of the apes', 'fantastic four']
# iter: 0/37 of epoch 299/300
# err: 1.454302
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `pirates of the caribbean at worlds end` : `['pirates of the caribbean on stranger tides', 'pirates of the caribbean dead mans chest', 'pirates of the caribbean the curse of the black pearl']`
# Reccomendation | rango : ['angels  demons', 'cradle 2 the grave', 'the devils tomb']
# iter: 1/37 of epoch 299/300
# err: 1.727018
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `spectre` : `['the art of war', 'kickass 2', 'the prince']`
# Reccomendation | the invasion : ['dragonball evolution', 'planet of the apes', 'mutant world']
# iter: 2/37 of epoch 299/300
# err: 1.378442
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the dark knight rises` : `['the dark knight', 'batman the dark knight returns part 2', 'batman  robin']`
# Reccomendation | evan almighty : ['cast away', 'swept away', 'away we go']
# iter: 3/37 of epoch 299/300
# err: 1.243645
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `john carter` : `['treasure planet', 'transformers', 'jupiter ascending']`
# Reccomendation | ace ventura when nature calls : ['awol72', 'swordfish', 'live free or die hard']
# iter: 4/37 of epoch 299/300
# err: 1.006333
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `spiderman 3` : `['forbidden kingdom', 'the forbidden kingdom', 'spiderman']`
# Reccomendation | the oxford murders : ['dragonball evolution', 'captain america the winter soldier', 'captain america civil war']
# iter: 5/37 of epoch 299/300
# err: 0.927198
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `tangled` : `['aladdin', 'valiant', 'gullivers travels']`
# Reccomendation | beverly hills cop iii : ['the dead undead', 'priest', 'aliens vs predator requiem']
# iter: 6/37 of epoch 299/300
# err: 1.279246
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `avengers age of ultron` : `['transformers age of extinction', 'the avengers', 'antman']`
# Reccomendation | on the road : ['the jungle book 2', 'madagascar', 'dwegons']
# iter: 7/37 of epoch 299/300
# err: 0.720314
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `harry potter and the halfblood prince` : `['harry potter and the philosophers stone', 'harry potter and the prisoner of azkaban', 'harry potter and the goblet of fire']`
# Reccomendation | ace ventura when nature calls : ['exit wounds', 'the french connection', 'faceoff']
# iter: 8/37 of epoch 299/300
# err: 0.843581
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `batman v superman dawn of justice` : `['superman returns', 'batman returns', 'superman']`
# Reccomendation | finding nemo : ['back to the future part ii', 'back to the future', 'shes the man']
# iter: 9/37 of epoch 299/300
# err: 0.798691
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `superman returns` : `['superman iii', 'superman ii', 'superman']`
# Reccomendation | margin call : ['windsor drive', 'hannibal rising', 'run hide die']
# iter: 10/37 of epoch 299/300
# err: 0.762595
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `quantum of solace` : `['spectre', 'the glimmer man', 'haywire']`
# Reccomendation | the informers : ['closer', 'americas sweethearts', 'four weddings and a funeral']
# iter: 11/37 of epoch 299/300
# err: 0.731790
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `pirates of the caribbean dead mans chest` : `['pirates of the caribbean the curse of the black pearl', 'pirates of the caribbean on stranger tides', 'pirates of the caribbean at worlds end']`
# Reccomendation | the innkeepers : ['vacation', 'nothing to lose', 'adventureland']
# iter: 12/37 of epoch 299/300
# err: 0.812881
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the lone ranger` : `['the legend of the lone ranger', 'space pirate captain harlock', 'space chimps']`
# Reccomendation | ace ventura when nature calls : ['swordfish', 'run hide die', 'taken 2']
# iter: 13/37 of epoch 299/300
# err: 1.071239
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `man of steel` : `['the wolverine', 'xmen', 'superman ii']`
# Reccomendation | ace ventura when nature calls : ['pain  gain', 'harsh times', 'i am wrath']
# iter: 14/37 of epoch 299/300
# err: 0.833828
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the chronicles of narnia prince caspian` : `['the chronicles of narnia the lion the witch and the wardrobe', 'the chronicles of narnia the voyage of the dawn treader', 'the spiderwick chronicles']`
# Reccomendation | ace ventura pet detective : ['mad max 2 the road warrior', 'mad max beyond thunderdome', 'virtuosity']
# iter: 15/37 of epoch 299/300
# err: 1.187602
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the avengers` : `['antman', 'xmen', 'the wolverine']`
# Reccomendation | uhf : ['someone like you', 'abcd any body can dance', 'my best friends girl']
# iter: 16/37 of epoch 299/300
# err: 0.970688
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `pirates of the caribbean on stranger tides` : `['pirates of the caribbean dead mans chest', 'pirates of the caribbean the curse of the black pearl', 'pirates of the caribbean at worlds end']`
# Reccomendation | the sound of music : ['neal n nikki', 'standing ovation', 'ramona and beezus']
# iter: 17/37 of epoch 299/300
# err: 0.738226
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `men in black 3` : `['twilight zone the movie', 'dawn of the crescent moon', 'the twilight saga new moon']`
# Reccomendation | the bucket list : ['kansas city', 'spring breakers', 'hurricane streets']
# iter: 18/37 of epoch 299/300
# err: 1.256754
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the hobbit the battle of the five armies` : `['the hobbit the desolation of smaug', 'the hobbit an unexpected journey', 'the lord of the rings the two towers']`
# Reccomendation | across the universe : ['american dreamz', 'diary of a wimpy kid', 'chairman of the board']
# iter: 19/37 of epoch 299/300
# err: 1.266317
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the amazing spiderman` : `['the amazing spiderman 2', 'spiderman 2', 'the wolverine']`
# Reccomendation | the blues brothers : ['the object of my affection', 'thumbsucker', 'big daddy']
# iter: 20/37 of epoch 299/300
# err: 0.889641
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `robin hood` : `['robin hood prince of thieves', 'black knight', 'the adventurer the curse of the midas box']`
# Reccomendation | bad santa : ['domestic disturbance', 'windsor drive', 'the lady from shanghai']
# iter: 21/37 of epoch 299/300
# err: 0.688650
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the hobbit the desolation of smaug` : `['the hobbit the battle of the five armies', 'the hobbit an unexpected journey', 'the lord of the rings the fellowship of the ring']`
# Reccomendation | idlewild : ['ace ventura pet detective', 'pcu', 'ace ventura when nature calls']
# iter: 22/37 of epoch 299/300
# err: 0.953800
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `the golden compass` : `['dragonheart', 'jack the giant slayer', 'eragon']`
# Reccomendation | source code : ['army of darkness', 'snow white a tale of terror', 'underworld rise of the lycans']
# iter: 23/37 of epoch 299/300
# err: 0.790003
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `king kong` : `['the monkey king 2', 'crocodile dundee ii', 'benji']`
# Reccomendation | the man with the iron fists : ['atlas shrugged part ii', 'atlas shrugged part iii who is john galt', 'the dark knight rises']
# iter: 24/37 of epoch 299/300
# err: 0.883772
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `titanic` : `['laws of attraction', 'crazybeautiful', 'raise the titanic']`
# Reccomendation | the sound of music : ['as it is in heaven', 'dancin its on', 'glitter']
# iter: 25/37 of epoch 299/300
# err: 0.689177
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `captain america civil war` : `['captain america the winter soldier', 'captain america the first avenger', 'antman']`
# Reccomendation | cats dont dance : ['henry  me', 'why i did not eat my father', 'cats dont dance']
# iter: 26/37 of epoch 299/300
# err: 0.827088
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `battleship` : `['space battleship yamato', 'ouija', 'no mans land the rise of reeker']`
# Reccomendation | lake placid : ['national lampoons vacation', 'national lampoon’s van wilder', 'national lampoons loaded weapon 1']
# iter: 27/37 of epoch 299/300
# err: 1.012630
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `jurassic world` : `['the lost world jurassic park', 'jurassic park', 'jurassic park iii']`
# Reccomendation | the oxford murders : ['valley of the wolves iraq', 'the longest day', 'red tails']
# iter: 28/37 of epoch 299/300
# err: 1.197770
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `skyfall` : `['16 blocks', 'the green hornet', 'quantum of solace']`
# Reccomendation | the kids are all right : ['mozarts sister', 'the merchant of venice', 'the bridge of san luis rey']
# iter: 29/37 of epoch 299/300
# err: 0.761783
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `spiderman 2` : `['the amazing spiderman 2', 'elektra', 'the amazing spiderman']`
# Reccomendation | gandhi my father : ['they', 'train', 'rec²']
# iter: 30/37 of epoch 299/300
# err: 0.721686
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `iron man 3` : `['iron man', 'iron man 2', 'thor the dark world']`
# Reccomendation | vera drake : ['enter the dangerous mind', 'the girl with the dragon tattoo', 'bangkok dangerous']
# iter: 31/37 of epoch 299/300
# err: 0.842838
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `alice in wonderland` : `['pan', 'hook', 'the bfg']`
# Reccomendation | across the universe : ['inside job', 'capitalism a love story', 'a low down dirty shame']
# iter: 32/37 of epoch 299/300
# err: 1.057691
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `xmen the last stand` : `['xmen', 'the wolverine', 'x2']`
# Reccomendation | the pledge : ['the lazarus effect', 'paranormal activity the marked ones', 'the evil dead']
# iter: 33/37 of epoch 299/300
# err: 1.083632
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `monsters university` : `['hoot', 'home on the range', 'poohs heffalump movie']`
# Reccomendation | idlewild : ['shine a light', 'my big fat independent movie', 'futuro beach']
# iter: 34/37 of epoch 299/300
# err: 0.633843
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `transformers revenge of the fallen` : `['transformers', 'the blood of heroes', 'predators']`
# Reccomendation | pans labyrinth : ['hoop dreams', 'high school musical', 'high school musical 2']
# iter: 35/37 of epoch 299/300
# err: 0.816079
#
# torch.Size([128, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `transformers age of extinction` : `['avengers age of ultron', 'transformers', 'the avengers']`
# Reccomendation | april fools day : ['hellraiser', 'underworld awakening', 'bloodrayne']
# iter: 36/37 of epoch 299/300
# err: 0.404825
#
# torch.Size([64, 1, 32])
# NETWORK FORWARDED
# Ground-Truth Similarity | `oz the great and powerful` : `['return to oz', 'happily never after', 'maleficent']`
# Reccomendation | kingdom of heaven : ['standing ovation', 'sunday school musical', 'from justin to kelly']
# iter: 37/37 of epoch 299/300
# err: 0.427156
